# %%
from helper_classes import Data
import util as ut

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten,Dropout
from tensorflow.keras.regularizers import l2


import warnings
import logging
from scipy import stats
import numpy as np
import random
import torch
from sklearn.preprocessing import MultiLabelBinarizer
random_state = 1
np.random.seed(random_state)
random.seed(random_state)
warnings.filterwarnings('ignore')

# %%
dataset='FB15K'
kg_root = 'KGs/'+dataset+'/'
dataset=Data(kg_root)

# %%
y=[]
x=[]

entitiy_idx=dict()

sub_obj_pairs= dataset.get_entity_pairs_with_predicates(dataset.train_data)
for s_o_pair, predicates in sub_obj_pairs.items():
    s,o=s_o_pair
    entitiy_idx.setdefault(s, len(entitiy_idx))
    entitiy_idx.setdefault(o, len(entitiy_idx))
    x.append([entitiy_idx[s],entitiy_idx[o]])
    y.append(list(predicates))
x=np.array(x)

# %%
x=np.array(x)
binarizer=MultiLabelBinarizer()
y=binarizer.fit_transform(y)

# %%
embedding_dim=50
model = Sequential()
model.add(Embedding(len(entitiy_idx), embedding_dim, input_length=2,activity_regularizer=l2(0.1)))
model.add(Flatten())
model.add(Dropout(.4))
model.add(Dense(embedding_dim*5, activation='relu',activity_regularizer=l2(0.1)))
model.add(Dropout(.4))
model.add(Dense(y.shape[1], activation='sigmoid'))
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2, 50)             747550
# _________________________________________________________________
# flatten (Flatten)            (None, 100)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 250)               25250
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1345)              337595
# =================================================================
# Total params: 1,110,395
# Trainable params: 1,110,395
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x, y, batch_size=1000, epochs= 30, use_multiprocessing=True,verbose=1,shuffle=True)
# Out:
# Train on 394804 samples
# Epoch 1/30
# 394804/394804 [==============================] - 19s 47us/sample - loss: 6.9710 - accuracy: 0.0344
# Epoch 2/30
# 394804/394804 [==============================] - 19s 48us/sample - loss: 4.3784 - accuracy: 0.3733
# Epoch 3/30
# 394804/394804 [==============================] - 19s 49us/sample - loss: 2.6117 - accuracy: 0.7256
# Epoch 4/30
# 394804/394804 [==============================] - 19s 49us/sample - loss: 2.1369 - accuracy: 0.7679
# Epoch 5/30
# 394804/394804 [==============================] - 21s 52us/sample - loss: 1.8823 - accuracy: 0.7888
# Epoch 6/30
# 394804/394804 [==============================] - 24s 60us/sample - loss: 1.7150 - accuracy: 0.8023
# Epoch 7/30
# 394804/394804 [==============================] - 22s 57us/sample - loss: 1.5956 - accuracy: 0.8090
# Epoch 8/30
# 394804/394804 [==============================] - 19s 49us/sample - loss: 1.5041 - accuracy: 0.8145
# Epoch 9/30
# 394804/394804 [==============================] - 24s 60us/sample - loss: 1.4331 - accuracy: 0.8190
# Epoch 10/30
# 394804/394804 [==============================] - 23s 58us/sample - loss: 1.3725 - accuracy: 0.8220
# Epoch 11/30
# 394804/394804 [==============================] - 20s 49us/sample - loss: 1.3227 - accuracy: 0.8252
# Epoch 12/30
# 394804/394804 [==============================] - 27s 69us/sample - loss: 1.2808 - accuracy: 0.8275
# Epoch 13/30
# 394804/394804 [==============================] - 26s 66us/sample - loss: 1.2439 - accuracy: 0.8295
# Epoch 14/30
# 394804/394804 [==============================] - 26s 67us/sample - loss: 1.2121 - accuracy: 0.8305
# Epoch 15/30
# 394804/394804 [==============================] - 28s 70us/sample - loss: 1.1846 - accuracy: 0.8318
# Epoch 16/30
# 394804/394804 [==============================] - 24s 60us/sample - loss: 1.1599 - accuracy: 0.8337
# Epoch 17/30
# 394804/394804 [==============================] - 22s 57us/sample - loss: 1.1377 - accuracy: 0.8342
# Epoch 18/30
# 394804/394804 [==============================] - 20s 52us/sample - loss: 1.1194 - accuracy: 0.8351
# Epoch 19/30
# 394804/394804 [==============================] - 25s 63us/sample - loss: 1.1004 - accuracy: 0.8371
# Epoch 20/30
# 394804/394804 [==============================] - 26s 66us/sample - loss: 1.0841 - accuracy: 0.8376
# Epoch 21/30
# 394804/394804 [==============================] - 27s 69us/sample - loss: 1.0707 - accuracy: 0.8384
# Epoch 22/30
# 394804/394804 [==============================] - 23s 59us/sample - loss: 1.0585 - accuracy: 0.8388
# Epoch 23/30
# 394804/394804 [==============================] - 23s 58us/sample - loss: 1.0465 - accuracy: 0.8391
# Epoch 24/30
# 394804/394804 [==============================] - 25s 62us/sample - loss: 1.0343 - accuracy: 0.8404
# Epoch 25/30
# 394804/394804 [==============================] - 25s 64us/sample - loss: 1.0240 - accuracy: 0.8415
# Epoch 26/30
# 394804/394804 [==============================] - 26s 66us/sample - loss: 1.0148 - accuracy: 0.8407
# Epoch 27/30
# 394804/394804 [==============================] - 25s 64us/sample - loss: 1.0066 - accuracy: 0.8417
# Epoch 28/30
# 394804/394804 [==============================] - 23s 59us/sample - loss: 0.9968 - accuracy: 0.8429
# Epoch 29/30
# 394804/394804 [==============================] - 22s 56us/sample - loss: 0.9904 - accuracy: 0.8424
# Epoch 30/30
# 394804/394804 [==============================] - 23s 59us/sample - loss: 0.9842 - accuracy: 0.8433

# %%
del x
del y

# %%
def evaluation(model,binarizer,dataset,triples):
    x_=[]
    y_=[]
    
    hits = []
    ranks=[]
    for i in range(10):
        hits.append([])

    rank_per_relation=dict()
        
    for i in triples:
        s,p,o=i
        x_.append((entitiy_idx[s],entitiy_idx[o]))
        y_.append(p)
    
    
    tensor_pred=torch.from_numpy(model.predict(np.array(x_)))
    
    _, ranked_predictions =tensor_pred.topk(k=len(binarizer.classes_))
    
    ranked_predictions=ranked_predictions.numpy()
    
    
    assert len(ranked_predictions)==len(y_)
    
    classes_=binarizer.classes_.tolist()
        
    for i in range(len(y_)):
        true_relation=y_[i]
        ith_class=classes_.index(true_relation)
        
        rank = np.where(ranked_predictions[i]==ith_class)[0]
        

        rank_per_relation.setdefault(true_relation, []).append(rank+1)
        
        ranks.append(rank+1)
        
        for hits_level in range(10):
            if rank <= hits_level:
                hits[hits_level].append(1.0)
    

    hits=np.array(hits)
    ranks=np.array(ranks)
    print('########## Relation Prediction Results ##########')

    print('Mean Hits @5: {0}'.format(sum(hits[4]) / (float(len(y_)))))
    print('Mean Hits @3: {0}'.format(sum(hits[2]) / (float(len(y_)))))
    print('Mean Hits @1: {0}'.format(sum(hits[0]) / (float(len(y_)))))
    print('Mean rank: {0}'.format(np.mean(ranks)))
    print('Mean reciprocal rank: {0}'.format(np.mean(1. / ranks)))
    
    print('########## Relation Prediction Analysis ##########')
    
    for pred, ranks in rank_per_relation.items():
        ranks=np.array(ranks)
        
        average_hit_at_1=np.sum(ranks==1)/len(ranks)
        average_hit_at_3=np.sum(ranks<=3)/len(ranks)
        average_hit_at_5=np.sum(ranks<=5)/len(ranks)
        
        print('{0}:\t Hits@1:\t{1:.3f}'.format(pred,average_hit_at_1))
        print('{0}:\t Hits@3:\t{1:.3f}'.format(pred,average_hit_at_3))
        print('{0}:\t Hits@5:\t{1:.3f}'.format(pred,average_hit_at_5))
        print('{0}:\t MRR:\t{1:.3f}\t number of occurrence {2}'.format(pred,np.mean(1. / ranks),len(ranks)))
        print('################################')

# %%
del dataset.train_data # free memory.
del dataset.valid_data

# %%
evaluation(model,binarizer,dataset,dataset.test_data)
# Out:
# ########## Relation Prediction Results ##########
# Mean Hits @5: 0.9871679842900916
# Mean Hits @3: 0.9492475157014441
# Mean Hits @1: 0.7343705032926479
# Mean rank: 1.5986693978432733
# Mean reciprocal rank: 0.8438899278081052
# ########## Relation Prediction Analysis ##########
# /award/award_nominee/award_nominations./award/award_nomination/award:	 Hits@1:	0.994
# /award/award_nominee/award_nominations./award/award_nomination/award:	 Hits@3:	1.000
# /award/award_nominee/award_nominations./award/award_nomination/award:	 Hits@5:	1.000
# /award/award_nominee/award_nominations./award/award_nomination/award:	 MRR:	0.997	 number of occurrence 1555
# ################################
# /base/activism/activist/area_of_activism:	 Hits@1:	0.800
# /base/activism/activist/area_of_activism:	 Hits@3:	1.000
# /base/activism/activist/area_of_activism:	 Hits@5:	1.000
# /base/activism/activist/area_of_activism:	 MRR:	0.889	 number of occurrence 15
# ################################
# /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month:	 Hits@1:	1.000
# /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month:	 Hits@3:	1.000
# /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month:	 Hits@5:	1.000
# /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month:	 MRR:	1.000	 number of occurrence 60
# ################################
# /music/performance_role/regular_performances./music/group_membership/group:	 Hits@1:	1.000
# /music/performance_role/regular_performances./music/group_membership/group:	 Hits@3:	1.000
# /music/performance_role/regular_performances./music/group_membership/group:	 Hits@5:	1.000
# /music/performance_role/regular_performances./music/group_membership/group:	 MRR:	1.000	 number of occurrence 167
# ################################
# /award/award_category/nominees./award/award_nomination/award_nominee:	 Hits@1:	0.988
# /award/award_category/nominees./award/award_nomination/award_nominee:	 Hits@3:	1.000
# /award/award_category/nominees./award/award_nomination/award_nominee:	 Hits@5:	1.000
# /award/award_category/nominees./award/award_nomination/award_nominee:	 MRR:	0.994	 number of occurrence 1451
# ################################
# /film/film/release_date_s./film/film_regional_release_date/film_release_region:	 Hits@1:	0.937
# /film/film/release_date_s./film/film_regional_release_date/film_release_region:	 Hits@3:	1.000
# /film/film/release_date_s./film/film_regional_release_date/film_release_region:	 Hits@5:	1.000
# /film/film/release_date_s./film/film_regional_release_date/film_release_region:	 MRR:	0.968	 number of occurrence 1591
# ################################
# /location/location/contains:	 Hits@1:	0.836
# /location/location/contains:	 Hits@3:	0.964
# /location/location/contains:	 Hits@5:	0.998
# /location/location/contains:	 MRR:	0.904	 number of occurrence 608
# ################################
# /film/actor/film./film/performance/film:	 Hits@1:	0.906
# /film/actor/film./film/performance/film:	 Hits@3:	0.983
# /film/actor/film./film/performance/film:	 Hits@5:	0.992
# /film/actor/film./film/performance/film:	 MRR:	0.943	 number of occurrence 1168
# ################################
# /award/award_category/nominees./award/award_nomination/nominated_for:	 Hits@1:	0.994
# /award/award_category/nominees./award/award_nomination/nominated_for:	 Hits@3:	1.000
# /award/award_category/nominees./award/award_nomination/nominated_for:	 Hits@5:	1.000
# /award/award_category/nominees./award/award_nomination/nominated_for:	 MRR:	0.997	 number of occurrence 1160
# ################################
# /soccer/football_team/current_roster./soccer/football_roster_position/position:	 Hits@1:	0.019
# /soccer/football_team/current_roster./soccer/football_roster_position/position:	 Hits@3:	0.876
# /soccer/football_team/current_roster./soccer/football_roster_position/position:	 Hits@5:	1.000
# /soccer/football_team/current_roster./soccer/football_roster_position/position:	 MRR:	0.346	 number of occurrence 266
# ################################
# /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office:	 Hits@1:	1.000
# /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office:	 Hits@3:	1.000
# /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office:	 Hits@5:	1.000
# /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office:	 MRR:	1.000	 number of occurrence 91
# ################################
# /government/government_office_category/officeholders./government/government_position_held/appointed_by:	 Hits@1:	0.400
# /government/government_office_category/officeholders./government/government_position_held/appointed_by:	 Hits@3:	1.000
# /government/government_office_category/officeholders./government/government_position_held/appointed_by:	 Hits@5:	1.000
# /government/government_office_category/officeholders./government/government_position_held/appointed_by:	 MRR:	0.700	 number of occurrence 5
# ################################
# /film/film/genre:	 Hits@1:	0.984
# /film/film/genre:	 Hits@3:	1.000
# /film/film/genre:	 Hits@5:	1.000
# /film/film/genre:	 MRR:	0.992	 number of occurrence 874
# ################################
# /sports/pro_athlete/teams./sports/sports_team_roster/team:	 Hits@1:	0.154
# /sports/pro_athlete/teams./sports/sports_team_roster/team:	 Hits@3:	0.250
# /sports/pro_athlete/teams./sports/sports_team_roster/team:	 Hits@5:	1.000
# /sports/pro_athlete/teams./sports/sports_team_roster/team:	 MRR:	0.377	 number of occurrence 52
# ################################
# /base/biblioness/bibs_location/country:	 Hits@1:	0.116
# /base/biblioness/bibs_location/country:	 Hits@3:	0.860
# /base/biblioness/bibs_location/country:	 Hits@5:	0.930
# /base/biblioness/bibs_location/country:	 MRR:	0.507	 number of occurrence 86
# ################################
# /award/award_nominee/award_nominations./award/award_nomination/award_nominee:	 Hits@1:	0.826
# /award/award_nominee/award_nominations./award/award_nomination/award_nominee:	 Hits@3:	0.996
# /award/award_nominee/award_nominations./award/award_nomination/award_nominee:	 Hits@5:	0.999
# /award/award_nominee/award_nominations./award/award_nomination/award_nominee:	 MRR:	0.911	 number of occurrence 2060
# ################################
# /base/locations/continents/countries_within:	 Hits@1:	0.476
# /base/locations/continents/countries_within:	 Hits@3:	1.000
# /base/locations/continents/countries_within:	 Hits@5:	1.000
# /base/locations/continents/countries_within:	 MRR:	0.738	 number of occurrence 21
# ################################
# /people/person/places_lived./people/place_lived/location:	 Hits@1:	0.739
# /people/person/places_lived./people/place_lived/location:	 Hits@3:	1.000
# /people/person/places_lived./people/place_lived/location:	 Hits@5:	1.000
# /people/person/places_lived./people/place_lived/location:	 MRR:	0.867	 number of occurrence 468
# ################################
# /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer:	 Hits@1:	0.857
# /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer:	 Hits@3:	1.000
# /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer:	 Hits@5:	1.000
# /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer:	 MRR:	0.929	 number of occurrence 35
# ################################
# /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal:	 Hits@1:	1.000
# /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal:	 Hits@3:	1.000
# /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal:	 Hits@5:	1.000
# /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal:	 MRR:	1.000	 number of occurrence 38
# ################################
# /location/location/containedby:	 Hits@1:	0.647
# /location/location/containedby:	 Hits@3:	0.989
# /location/location/containedby:	 Hits@5:	1.000
# /location/location/containedby:	 MRR:	0.814	 number of occurrence 618
# ################################
# /location/location/time_zones:	 Hits@1:	1.000
# /location/location/time_zones:	 Hits@3:	1.000
# /location/location/time_zones:	 Hits@5:	1.000
# /location/location/time_zones:	 MRR:	1.000	 number of occurrence 137
# ################################
# /sports/sports_team/roster./baseball/baseball_roster_position/position:	 Hits@1:	0.950
# /sports/sports_team/roster./baseball/baseball_roster_position/position:	 Hits@3:	1.000
# /sports/sports_team/roster./baseball/baseball_roster_position/position:	 Hits@5:	1.000
# /sports/sports_team/roster./baseball/baseball_roster_position/position:	 MRR:	0.975	 number of occurrence 20
# ################################
# /base/culturalevent/event/entity_involved:	 Hits@1:	0.135
# /base/culturalevent/event/entity_involved:	 Hits@3:	0.973
# /base/culturalevent/event/entity_involved:	 Hits@5:	1.000
# /base/culturalevent/event/entity_involved:	 MRR:	0.538	 number of occurrence 37
# ################################
# /base/aareas/schema/administrative_area/administrative_parent:	 Hits@1:	0.293
# /base/aareas/schema/administrative_area/administrative_parent:	 Hits@3:	0.653
# /base/aareas/schema/administrative_area/administrative_parent:	 Hits@5:	0.893
# /base/aareas/schema/administrative_area/administrative_parent:	 MRR:	0.513	 number of occurrence 75
# ################################
# /sports/sports_team/colors:	 Hits@1:	0.987
# /sports/sports_team/colors:	 Hits@3:	1.000
# /sports/sports_team/colors:	 Hits@5:	1.000
# /sports/sports_team/colors:	 MRR:	0.994	 number of occurrence 77
# ################################
# /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency:	 Hits@1:	0.106
# /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency:	 Hits@3:	0.936
# /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency:	 Hits@5:	1.000
# /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency:	 MRR:	0.426	 number of occurrence 47
# ################################
# /award/award_ceremony/awards_presented./award/award_honor/honored_for:	 Hits@1:	1.000
# /award/award_ceremony/awards_presented./award/award_honor/honored_for:	 Hits@3:	1.000
# /award/award_ceremony/awards_presented./award/award_honor/honored_for:	 Hits@5:	1.000
# /award/award_ceremony/awards_presented./award/award_honor/honored_for:	 MRR:	1.000	 number of occurrence 121
# ################################
# /olympics/olympic_games/participating_countries:	 Hits@1:	0.586
# /olympics/olympic_games/participating_countries:	 Hits@3:	1.000
# /olympics/olympic_games/participating_countries:	 Hits@5:	1.000
# /olympics/olympic_games/participating_countries:	 MRR:	0.756	 number of occurrence 58
# ################################
# /education/educational_institution/students_graduates./education/education/major_field_of_study:	 Hits@1:	1.000
# /education/educational_institution/students_graduates./education/education/major_field_of_study:	 Hits@3:	1.000
# /education/educational_institution/students_graduates./education/education/major_field_of_study:	 Hits@5:	1.000
# /education/educational_institution/students_graduates./education/education/major_field_of_study:	 MRR:	1.000	 number of occurrence 322
# ################################
# /location/statistical_region/religions./location/religion_percentage/religion:	 Hits@1:	1.000
# /location/statistical_region/religions./location/religion_percentage/religion:	 Hits@3:	1.000
# /location/statistical_region/religions./location/religion_percentage/religion:	 Hits@5:	1.000
# /location/statistical_region/religions./location/religion_percentage/religion:	 MRR:	1.000	 number of occurrence 60
# ################################
# /military/military_conflict/combatants./military/military_combatant_group/combatants:	 Hits@1:	0.958
# /military/military_conflict/combatants./military/military_combatant_group/combatants:	 Hits@3:	1.000
# /military/military_conflict/combatants./military/military_combatant_group/combatants:	 Hits@5:	1.000
# /military/military_conflict/combatants./military/military_combatant_group/combatants:	 MRR:	0.979	 number of occurrence 48
# ################################
# /award/award_category/winners./award/award_honor/ceremony:	 Hits@1:	1.000
# /award/award_category/winners./award/award_honor/ceremony:	 Hits@3:	1.000
# /award/award_category/winners./award/award_honor/ceremony:	 Hits@5:	1.000
# /award/award_category/winners./award/award_honor/ceremony:	 MRR:	1.000	 number of occurrence 323
# ################################
# /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy:	 Hits@1:	1.000
# /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy:	 Hits@3:	1.000
# /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy:	 Hits@5:	1.000
# /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy:	 MRR:	1.000	 number of occurrence 50
# ################################
# /influence/influence_node/influenced_by:	 Hits@1:	0.885
# /influence/influence_node/influenced_by:	 Hits@3:	0.988
# /influence/influence_node/influenced_by:	 Hits@5:	0.996
# /influence/influence_node/influenced_by:	 MRR:	0.938	 number of occurrence 244
# ################################
# /people/person/place_of_birth:	 Hits@1:	0.334
# /people/person/place_of_birth:	 Hits@3:	1.000
# /people/person/place_of_birth:	 Hits@5:	1.000
# /people/person/place_of_birth:	 MRR:	0.659	 number of occurrence 299
# ################################
# /american_football/football_team/historical_coaching_staff./american_football/football_historical_coach_position/position:	 Hits@1:	1.000
# /american_football/football_team/historical_coaching_staff./american_football/football_historical_coach_position/position:	 Hits@3:	1.000
# /american_football/football_team/historical_coaching_staff./american_football/football_historical_coach_position/position:	 Hits@5:	1.000
# /american_football/football_team/historical_coaching_staff./american_football/football_historical_coach_position/position:	 MRR:	1.000	 number of occurrence 8
# ################################
# /people/cause_of_death/people:	 Hits@1:	0.990
# /people/cause_of_death/people:	 Hits@3:	1.000
# /people/cause_of_death/people:	 Hits@5:	1.000
# /people/cause_of_death/people:	 MRR:	0.995	 number of occurrence 98
# ################################
# /education/educational_institution/school_type:	 Hits@1:	1.000
# /education/educational_institution/school_type:	 Hits@3:	1.000
# /education/educational_institution/school_type:	 Hits@5:	1.000
# /education/educational_institution/school_type:	 MRR:	1.000	 number of occurrence 81
# ################################
# /film/film/prequel:	 Hits@1:	0.160
# /film/film/prequel:	 Hits@3:	0.920
# /film/film/prequel:	 Hits@5:	1.000
# /film/film/prequel:	 MRR:	0.473	 number of occurrence 25
# ################################
# /people/person/profession:	 Hits@1:	0.998
# /people/person/profession:	 Hits@3:	0.998
# /people/person/profession:	 Hits@5:	0.999
# /people/person/profession:	 MRR:	0.998	 number of occurrence 1384
# ################################
# /award/award_nominee/award_nominations./award/award_nomination/nominated_for:	 Hits@1:	0.201
# /award/award_nominee/award_nominations./award/award_nomination/nominated_for:	 Hits@3:	0.973
# /award/award_nominee/award_nominations./award/award_nomination/nominated_for:	 Hits@5:	0.999
# /award/award_nominee/award_nominations./award/award_nomination/nominated_for:	 MRR:	0.575	 number of occurrence 743
# ################################
# /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film:	 Hits@1:	0.982
# /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film:	 Hits@3:	0.996
# /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film:	 Hits@5:	1.000
# /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film:	 MRR:	0.990	 number of occurrence 280
# ################################
# /soccer/football_player/current_team./sports/sports_team_roster/team:	 Hits@1:	0.000
# /soccer/football_player/current_team./sports/sports_team_roster/team:	 Hits@3:	0.621
# /soccer/football_player/current_team./sports/sports_team_roster/team:	 Hits@5:	1.000
# /soccer/football_player/current_team./sports/sports_team_roster/team:	 MRR:	0.325	 number of occurrence 58
# ################################
# /tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type:	 Hits@1:	1.000
# /tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type:	 Hits@3:	1.000
# /tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type:	 Hits@5:	1.000
# /tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type:	 MRR:	1.000	 number of occurrence 22
# ################################
# /film/film/edited_by:	 Hits@1:	0.640
# /film/film/edited_by:	 Hits@3:	0.760
# /film/film/edited_by:	 Hits@5:	0.920
# /film/film/edited_by:	 MRR:	0.725	 number of occurrence 25
# ################################
# /award/award_winning_work/awards_won./award/award_honor/ceremony:	 Hits@1:	1.000
# /award/award_winning_work/awards_won./award/award_honor/ceremony:	 Hits@3:	1.000
# /award/award_winning_work/awards_won./award/award_honor/ceremony:	 Hits@5:	1.000
# /award/award_winning_work/awards_won./award/award_honor/ceremony:	 MRR:	1.000	 number of occurrence 123
# ################################
# /sports/sports_team/roster./basketball/basketball_roster_position/position:	 Hits@1:	0.000
# /sports/sports_team/roster./basketball/basketball_roster_position/position:	 Hits@3:	1.000
# /sports/sports_team/roster./basketball/basketball_roster_position/position:	 Hits@5:	1.000
# /sports/sports_team/roster./basketball/basketball_roster_position/position:	 MRR:	0.373	 number of occurrence 21
# ################################
# /sports/sports_team/sport:	 Hits@1:	1.000
# /sports/sports_team/sport:	 Hits@3:	1.000
# /sports/sports_team/sport:	 Hits@5:	1.000
# /sports/sports_team/sport:	 MRR:	1.000	 number of occurrence 53
# ################################
# /people/ethnicity/people:	 Hits@1:	1.000
# /people/ethnicity/people:	 Hits@3:	1.000
# /people/ethnicity/people:	 Hits@5:	1.000
# /people/ethnicity/people:	 MRR:	1.000	 number of occurrence 252
# ################################
# /film/film/estimated_budget./measurement_unit/dated_money_value/currency:	 Hits@1:	1.000
# /film/film/estimated_budget./measurement_unit/dated_money_value/currency:	 Hits@3:	1.000
# /film/film/estimated_budget./measurement_unit/dated_money_value/currency:	 Hits@5:	1.000
# /film/film/estimated_budget./measurement_unit/dated_money_value/currency:	 MRR:	1.000	 number of occurrence 151
# ################################
# /organization/organization_member/member_of./organization/organization_membership/organization:	 Hits@1:	1.000
# /organization/organization_member/member_of./organization/organization_membership/organization:	 Hits@3:	1.000
# /organization/organization_member/member_of./organization/organization_membership/organization:	 Hits@5:	1.000
# /organization/organization_member/member_of./organization/organization_membership/organization:	 MRR:	1.000	 number of occurrence 107
# ################################
# /people/deceased_person/place_of_death:	 Hits@1:	0.182
# /people/deceased_person/place_of_death:	 Hits@3:	0.864
# /people/deceased_person/place_of_death:	 Hits@5:	0.989
# /people/deceased_person/place_of_death:	 MRR:	0.466	 number of occurrence 88
# ################################
# /government/government_office_category/officeholders./government/government_position_held/legislative_sessions:	 Hits@1:	1.000
# /government/government_office_category/officeholders./government/government_position_held/legislative_sessions:	 Hits@3:	1.000
# /government/government_office_category/officeholders./government/government_position_held/legislative_sessions:	 Hits@5:	1.000
# /government/government_office_category/officeholders./government/government_position_held/legislative_sessions:	 MRR:	1.000	 number of occurrence 10
# ################################
# /film/film/executive_produced_by:	 Hits@1:	0.396
# /film/film/executive_produced_by:	 Hits@3:	0.723
# /film/film/executive_produced_by:	 Hits@5:	0.861
# /film/film/executive_produced_by:	 MRR:	0.601	 number of occurrence 101
# ################################
# /music/record_label/artist:	 Hits@1:	0.993
# /music/record_label/artist:	 Hits@3:	1.000
# /music/record_label/artist:	 Hits@5:	1.000
# /music/record_label/artist:	 MRR:	0.995	 number of occurrence 270
# ################################
# /award/award_nominated_work/award_nominations./award/award_nomination/award:	 Hits@1:	0.994
# /award/award_nominated_work/award_nominations./award/award_nomination/award:	 Hits@3:	1.000
# /award/award_nominated_work/award_nominations./award/award_nomination/award:	 Hits@5:	1.000
# /award/award_nominated_work/award_nominations./award/award_nomination/award:	 MRR:	0.997	 number of occurrence 1190
# ################################
# /film/film/starring./film/performance/actor:	 Hits@1:	0.936
# /film/film/starring./film/performance/actor:	 Hits@3:	0.982
# /film/film/starring./film/performance/actor:	 Hits@5:	0.994
# /film/film/starring./film/performance/actor:	 MRR:	0.959	 number of occurrence 1123
# ################################
# /award/award_winning_work/awards_won./award/award_honor/award:	 Hits@1:	0.133
# /award/award_winning_work/awards_won./award/award_honor/award:	 Hits@3:	1.000
# /award/award_winning_work/awards_won./award/award_honor/award:	 Hits@5:	1.000
# /award/award_winning_work/awards_won./award/award_honor/award:	 MRR:	0.566	 number of occurrence 400
# ################################
# /film/film/featured_film_locations:	 Hits@1:	0.894
# /film/film/featured_film_locations:	 Hits@3:	0.952
# /film/film/featured_film_locations:	 Hits@5:	0.981
# /film/film/featured_film_locations:	 MRR:	0.925	 number of occurrence 104
# ################################
# /film/film/production_companies:	 Hits@1:	0.381
# /film/film/production_companies:	 Hits@3:	0.994
# /film/film/production_companies:	 Hits@5:	0.994
# /film/film/production_companies:	 MRR:	0.689	 number of occurrence 181
# ################################
# /film/film/film_festivals:	 Hits@1:	1.000
# /film/film/film_festivals:	 Hits@3:	1.000
# /film/film/film_festivals:	 Hits@5:	1.000
# /film/film/film_festivals:	 MRR:	1.000	 number of occurrence 24
# ################################
# /award/award_nominated_work/award_nominations./award/award_nomination/award_nominee:	 Hits@1:	0.173
# /award/award_nominated_work/award_nominations./award/award_nomination/award_nominee:	 Hits@3:	0.968
# /award/award_nominated_work/award_nominations./award/award_nomination/award_nominee:	 Hits@5:	0.996
# /award/award_nominated_work/award_nominations./award/award_nomination/award_nominee:	 MRR:	0.560	 number of occurrence 751
# ################################
# /sports/sports_position/players./sports/sports_team_roster/team:	 Hits@1:	0.159
# /sports/sports_position/players./sports/sports_team_roster/team:	 Hits@3:	0.946
# /sports/sports_position/players./sports/sports_team_roster/team:	 Hits@5:	1.000
# /sports/sports_position/players./sports/sports_team_roster/team:	 MRR:	0.559	 number of occurrence 429
# ################################
# /people/person/gender:	 Hits@1:	1.000
# /people/person/gender:	 Hits@3:	1.000
# /people/person/gender:	 Hits@5:	1.000
# /people/person/gender:	 MRR:	1.000	 number of occurrence 436
# ################################
# /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor:	 Hits@1:	0.722
# /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor:	 Hits@3:	0.987
# /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor:	 Hits@5:	0.993
# /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor:	 MRR:	0.841	 number of occurrence 151
# ################################
# /education/educational_institution_campus/educational_institution:	 Hits@1:	0.132
# /education/educational_institution_campus/educational_institution:	 Hits@3:	1.000
# /education/educational_institution_campus/educational_institution:	 Hits@5:	1.000
# /education/educational_institution_campus/educational_institution:	 MRR:	0.566	 number of occurrence 68
# ################################
# /influence/influence_node/influenced:	 Hits@1:	0.838
# /influence/influence_node/influenced:	 Hits@3:	0.962
# /influence/influence_node/influenced:	 Hits@5:	0.987
# /influence/influence_node/influenced:	 MRR:	0.905	 number of occurrence 235
# ################################
# /music/musical_group/member./music/group_membership/role:	 Hits@1:	1.000
# /music/musical_group/member./music/group_membership/role:	 Hits@3:	1.000
# /music/musical_group/member./music/group_membership/role:	 Hits@5:	1.000
# /music/musical_group/member./music/group_membership/role:	 MRR:	1.000	 number of occurrence 162
# ################################
# /film/film_genre/films_in_this_genre:	 Hits@1:	0.988
# /film/film_genre/films_in_this_genre:	 Hits@3:	1.000
# /film/film_genre/films_in_this_genre:	 Hits@5:	1.000
# /film/film_genre/films_in_this_genre:	 MRR:	0.994	 number of occurrence 885
# ################################
# /film/director/film:	 Hits@1:	0.236
# /film/director/film:	 Hits@3:	0.783
# /film/director/film:	 Hits@5:	0.962
# /film/director/film:	 MRR:	0.510	 number of occurrence 106
# ################################
# /film/film/distributors./film/film_film_distributor_relationship/distributor:	 Hits@1:	0.977
# /film/film/distributors./film/film_film_distributor_relationship/distributor:	 Hits@3:	0.997
# /film/film/distributors./film/film_film_distributor_relationship/distributor:	 Hits@5:	0.997
# /film/film/distributors./film/film_film_distributor_relationship/distributor:	 MRR:	0.986	 number of occurrence 299
# ################################
# /film/film/music:	 Hits@1:	0.826
# /film/film/music:	 Hits@3:	0.931
# /film/film/music:	 Hits@5:	0.979
# /film/film/music:	 MRR:	0.884	 number of occurrence 144
# ################################
# /award/award_winning_work/awards_won./award/award_honor/award_winner:	 Hits@1:	0.011
# /award/award_winning_work/awards_won./award/award_honor/award_winner:	 Hits@3:	0.832
# /award/award_winning_work/awards_won./award/award_honor/award_winner:	 Hits@5:	0.979
# /award/award_winning_work/awards_won./award/award_honor/award_winner:	 MRR:	0.352	 number of occurrence 380
# ################################
# /award/award_winner/awards_won./award/award_honor/honored_for:	 Hits@1:	0.015
# /award/award_winner/awards_won./award/award_honor/honored_for:	 Hits@3:	0.833
# /award/award_winner/awards_won./award/award_honor/honored_for:	 Hits@5:	0.967
# /award/award_winner/awards_won./award/award_honor/honored_for:	 MRR:	0.345	 number of occurrence 389
# ################################
# /film/film/language:	 Hits@1:	0.982
# /film/film/language:	 Hits@3:	0.997
# /film/film/language:	 Hits@5:	0.997
# /film/film/language:	 MRR:	0.989	 number of occurrence 326
# ################################
# /award/award_category/winners./award/award_honor/award_winner:	 Hits@1:	0.155
# /award/award_category/winners./award/award_honor/award_winner:	 Hits@3:	1.000
# /award/award_category/winners./award/award_honor/award_winner:	 Hits@5:	1.000
# /award/award_category/winners./award/award_honor/award_winner:	 MRR:	0.577	 number of occurrence 685
# ################################
# /organization/non_profit_organization/registered_with./organization/non_profit_registration/registering_agency:	 Hits@1:	1.000
# /organization/non_profit_organization/registered_with./organization/non_profit_registration/registering_agency:	 Hits@3:	1.000
# /organization/non_profit_organization/registered_with./organization/non_profit_registration/registering_agency:	 Hits@5:	1.000
# /organization/non_profit_organization/registered_with./organization/non_profit_registration/registering_agency:	 MRR:	1.000	 number of occurrence 22
# ################################
# /olympics/olympic_games/sports:	 Hits@1:	0.924
# /olympics/olympic_games/sports:	 Hits@3:	1.000
# /olympics/olympic_games/sports:	 Hits@5:	1.000
# /olympics/olympic_games/sports:	 MRR:	0.962	 number of occurrence 79
# ################################
# /music/genre/parent_genre:	 Hits@1:	0.910
# /music/genre/parent_genre:	 Hits@3:	1.000
# /music/genre/parent_genre:	 Hits@5:	1.000
# /music/genre/parent_genre:	 MRR:	0.955	 number of occurrence 100
# ################################
# /education/field_of_study/students_majoring./education/education/major_field_of_study:	 Hits@1:	1.000
# /education/field_of_study/students_majoring./education/education/major_field_of_study:	 Hits@3:	1.000
# /education/field_of_study/students_majoring./education/education/major_field_of_study:	 Hits@5:	1.000
# /education/field_of_study/students_majoring./education/education/major_field_of_study:	 MRR:	1.000	 number of occurrence 53
# ################################
# /government/legislative_session/members./government/government_position_held/district_represented:	 Hits@1:	1.000
# /government/legislative_session/members./government/government_position_held/district_represented:	 Hits@3:	1.000
# /government/legislative_session/members./government/government_position_held/district_represented:	 Hits@5:	1.000
# /government/legislative_session/members./government/government_position_held/district_represented:	 MRR:	1.000	 number of occurrence 117
# ################################
# /food/food/nutrients./food/nutrition_fact/nutrient:	 Hits@1:	1.000
# /food/food/nutrients./food/nutrition_fact/nutrient:	 Hits@3:	1.000
# /food/food/nutrients./food/nutrition_fact/nutrient:	 Hits@5:	1.000
# /food/food/nutrients./food/nutrition_fact/nutrient:	 MRR:	1.000	 number of occurrence 105
# ################################
# /education/educational_degree/people_with_this_degree./education/education/specialization:	 Hits@1:	0.100
# /education/educational_degree/people_with_this_degree./education/education/specialization:	 Hits@3:	0.800
# /education/educational_degree/people_with_this_degree./education/education/specialization:	 Hits@5:	0.800
# /education/educational_degree/people_with_this_degree./education/education/specialization:	 MRR:	0.405	 number of occurrence 10
# ################################
# /education/educational_degree/people_with_this_degree./education/education/institution:	 Hits@1:	1.000
# /education/educational_degree/people_with_this_degree./education/education/institution:	 Hits@3:	1.000
# /education/educational_degree/people_with_this_degree./education/education/institution:	 Hits@5:	1.000
# /education/educational_degree/people_with_this_degree./education/education/institution:	 MRR:	1.000	 number of occurrence 287
# ################################
# /tv/tv_producer_type/tv_producers_of_this_type./tv/tv_producer_term/producer:	 Hits@1:	1.000
# /tv/tv_producer_type/tv_producers_of_this_type./tv/tv_producer_term/producer:	 Hits@3:	1.000
# /tv/tv_producer_type/tv_producers_of_this_type./tv/tv_producer_term/producer:	 Hits@5:	1.000
# /tv/tv_producer_type/tv_producers_of_this_type./tv/tv_producer_term/producer:	 MRR:	1.000	 number of occurrence 28
# ################################
# /ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position:	 Hits@1:	0.000
# /ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position:	 Hits@3:	0.786
# /ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position:	 Hits@5:	1.000
# /ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position:	 MRR:	0.315	 number of occurrence 14
# ################################
# /media_common/netflix_genre/titles:	 Hits@1:	0.339
# /media_common/netflix_genre/titles:	 Hits@3:	0.993
# /media_common/netflix_genre/titles:	 Hits@5:	0.997
# /media_common/netflix_genre/titles:	 MRR:	0.667	 number of occurrence 298
# ################################
# /people/person/spouse_s./people/marriage/type_of_union:	 Hits@1:	1.000
# /people/person/spouse_s./people/marriage/type_of_union:	 Hits@3:	1.000
# /people/person/spouse_s./people/marriage/type_of_union:	 Hits@5:	1.000
# /people/person/spouse_s./people/marriage/type_of_union:	 MRR:	1.000	 number of occurrence 347
# ################################
# /soccer/football_team/current_roster./soccer/football_roster_position/player:	 Hits@1:	0.000
# /soccer/football_team/current_roster./soccer/football_roster_position/player:	 Hits@3:	0.953
# /soccer/football_team/current_roster./soccer/football_roster_position/player:	 Hits@5:	1.000
# /soccer/football_team/current_roster./soccer/football_roster_position/player:	 MRR:	0.345	 number of occurrence 64
# ################################
# /education/educational_institution/students_graduates./education/education/student:	 Hits@1:	1.000
# /education/educational_institution/students_graduates./education/education/student:	 Hits@3:	1.000
# /education/educational_institution/students_graduates./education/education/student:	 Hits@5:	1.000
# /education/educational_institution/students_graduates./education/education/student:	 MRR:	1.000	 number of occurrence 312
# ################################
# /film/film/directed_by:	 Hits@1:	0.243
# /film/film/directed_by:	 Hits@3:	0.784
# /film/film/directed_by:	 Hits@5:	0.982
# /film/film/directed_by:	 MRR:	0.506	 number of occurrence 111
# ################################
# /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program:	 Hits@1:	0.216
# /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program:	 Hits@3:	0.622
# /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program:	 Hits@5:	0.946
# /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program:	 MRR:	0.453	 number of occurrence 37
# ################################
# /location/location/people_born_here:	 Hits@1:	1.000
# /location/location/people_born_here:	 Hits@3:	1.000
# /location/location/people_born_here:	 Hits@5:	1.000
# /location/location/people_born_here:	 MRR:	1.000	 number of occurrence 295
# ################################
# /award/award_winner/awards_won./award/award_honor/award_winner:	 Hits@1:	0.237
# /award/award_winner/awards_won./award/award_honor/award_winner:	 Hits@3:	0.984
# /award/award_winner/awards_won./award/award_honor/award_winner:	 Hits@5:	0.995
# /award/award_winner/awards_won./award/award_honor/award_winner:	 MRR:	0.611	 number of occurrence 1045
# ################################
# /people/person/education./education/education/institution:	 Hits@1:	0.997
# /people/person/education./education/education/institution:	 Hits@3:	1.000
# /people/person/education./education/education/institution:	 Hits@5:	1.000
# /people/person/education./education/education/institution:	 MRR:	0.999	 number of occurrence 358
# ################################
# /sports/sports_team/roster./sports/sports_team_roster/position:	 Hits@1:	0.031
# /sports/sports_team/roster./sports/sports_team_roster/position:	 Hits@3:	0.049
# /sports/sports_team/roster./sports/sports_team_roster/position:	 Hits@5:	0.907
# /sports/sports_team/roster./sports/sports_team_roster/position:	 MRR:	0.265	 number of occurrence 453
# ################################
# /award/award_ceremony/awards_presented./award/award_honor/award_winner:	 Hits@1:	1.000
# /award/award_ceremony/awards_presented./award/award_honor/award_winner:	 Hits@3:	1.000
# /award/award_ceremony/awards_presented./award/award_honor/award_winner:	 Hits@5:	1.000
# /award/award_ceremony/awards_presented./award/award_honor/award_winner:	 MRR:	1.000	 number of occurrence 318
# ################################
# /music/genre/artists:	 Hits@1:	0.999
# /music/genre/artists:	 Hits@3:	0.999
# /music/genre/artists:	 Hits@5:	1.000
# /music/genre/artists:	 MRR:	0.999	 number of occurrence 679
# ################################
# /sports/sports_team/roster./american_football/football_roster_position/position:	 Hits@1:	0.014
# /sports/sports_team/roster./american_football/football_roster_position/position:	 Hits@3:	0.817
# /sports/sports_team/roster./american_football/football_roster_position/position:	 Hits@5:	0.986
# /sports/sports_team/roster./american_football/football_roster_position/position:	 MRR:	0.446	 number of occurrence 71
# ################################
# /people/person/nationality:	 Hits@1:	0.988
# /people/person/nationality:	 Hits@3:	1.000
# /people/person/nationality:	 Hits@5:	1.000
# /people/person/nationality:	 MRR:	0.993	 number of occurrence 508
# ################################
# /music/artist/track_contributions./music/track_contribution/role:	 Hits@1:	0.633
# /music/artist/track_contributions./music/track_contribution/role:	 Hits@3:	0.996
# /music/artist/track_contributions./music/track_contribution/role:	 Hits@5:	1.000
# /music/artist/track_contributions./music/track_contribution/role:	 MRR:	0.806	 number of occurrence 226
# ################################
# /music/artist/label:	 Hits@1:	0.993
# /music/artist/label:	 Hits@3:	0.997
# /music/artist/label:	 Hits@5:	0.997
# /music/artist/label:	 MRR:	0.994	 number of occurrence 286
# ################################
# /organization/organization/headquarters./location/mailing_address/citytown:	 Hits@1:	0.510
# /organization/organization/headquarters./location/mailing_address/citytown:	 Hits@3:	0.970
# /organization/organization/headquarters./location/mailing_address/citytown:	 Hits@5:	1.000
# /organization/organization/headquarters./location/mailing_address/citytown:	 MRR:	0.744	 number of occurrence 100
# ################################
# /sports/sports_league/teams./sports/sports_league_participation/team:	 Hits@1:	0.750
# /sports/sports_league/teams./sports/sports_league_participation/team:	 Hits@3:	1.000
# /sports/sports_league/teams./sports/sports_league_participation/team:	 Hits@5:	1.000
# /sports/sports_league/teams./sports/sports_league_participation/team:	 MRR:	0.875	 number of occurrence 16
# ################################
# /organization/organization_founder/organizations_founded:	 Hits@1:	0.188
# /organization/organization_founder/organizations_founded:	 Hits@3:	0.812
# /organization/organization_founder/organizations_founded:	 Hits@5:	0.938
# /organization/organization_founder/organizations_founded:	 MRR:	0.497	 number of occurrence 16
# ################################
# /common/topic/webpage./common/webpage/category:	 Hits@1:	1.000
# /common/topic/webpage./common/webpage/category:	 Hits@3:	1.000
# /common/topic/webpage./common/webpage/category:	 Hits@5:	1.000
# /common/topic/webpage./common/webpage/category:	 MRR:	1.000	 number of occurrence 708
# ################################
# /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant:	 Hits@1:	0.021
# /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant:	 Hits@3:	0.542
# /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant:	 Hits@5:	0.896
# /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant:	 MRR:	0.318	 number of occurrence 48
# ################################
# /user/jg/default_domain/olympic_games/sports:	 Hits@1:	0.048
# /user/jg/default_domain/olympic_games/sports:	 Hits@3:	1.000
# /user/jg/default_domain/olympic_games/sports:	 Hits@5:	1.000
# /user/jg/default_domain/olympic_games/sports:	 MRR:	0.521	 number of occurrence 63
# ################################
# /sports/sports_team_location/teams:	 Hits@1:	1.000
# /sports/sports_team_location/teams:	 Hits@3:	1.000
# /sports/sports_team_location/teams:	 Hits@5:	1.000
# /sports/sports_team_location/teams:	 MRR:	1.000	 number of occurrence 54
# ################################
# /music/performance_role/track_performances./music/track_contribution/role:	 Hits@1:	0.895
# /music/performance_role/track_performances./music/track_contribution/role:	 Hits@3:	0.998
# /music/performance_role/track_performances./music/track_contribution/role:	 Hits@5:	1.000
# /music/performance_role/track_performances./music/track_contribution/role:	 MRR:	0.946	 number of occurrence 478
# ################################
# /award/award_ceremony/awards_presented./award/award_honor/award:	 Hits@1:	1.000
# /award/award_ceremony/awards_presented./award/award_honor/award:	 Hits@3:	1.000
# /award/award_ceremony/awards_presented./award/award_honor/award:	 Hits@5:	1.000
# /award/award_ceremony/awards_presented./award/award_honor/award:	 MRR:	1.000	 number of occurrence 349
# ################################
# /education/educational_institution/campuses:	 Hits@1:	0.767
# /education/educational_institution/campuses:	 Hits@3:	0.983
# /education/educational_institution/campuses:	 Hits@5:	1.000
# /education/educational_institution/campuses:	 MRR:	0.879	 number of occurrence 60
# ################################
# /music/artist/genre:	 Hits@1:	0.996
# /music/artist/genre:	 Hits@3:	0.997
# /music/artist/genre:	 Hits@5:	0.997
# /music/artist/genre:	 MRR:	0.997	 number of occurrence 757
# ################################
# /film/music_contributor/film:	 Hits@1:	0.895
# /film/music_contributor/film:	 Hits@3:	0.955
# /film/music_contributor/film:	 Hits@5:	0.992
# /film/music_contributor/film:	 MRR:	0.933	 number of occurrence 133
# ################################
# /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics:	 Hits@1:	0.737
# /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics:	 Hits@3:	1.000
# /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics:	 Hits@5:	1.000
# /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics:	 MRR:	0.853	 number of occurrence 118
# ################################
# /sports/pro_athlete/teams./soccer/football_roster_position/team:	 Hits@1:	0.694
# /sports/pro_athlete/teams./soccer/football_roster_position/team:	 Hits@3:	1.000
# /sports/pro_athlete/teams./soccer/football_roster_position/team:	 Hits@5:	1.000
# /sports/pro_athlete/teams./soccer/football_roster_position/team:	 MRR:	0.839	 number of occurrence 62
# ################################
# /film/film/story_by:	 Hits@1:	0.519
# /film/film/story_by:	 Hits@3:	0.815
# /film/film/story_by:	 Hits@5:	0.870
# /film/film/story_by:	 MRR:	0.671	 number of occurrence 54
# ################################
# /medicine/disease/parent_disease:	 Hits@1:	0.889
# /medicine/disease/parent_disease:	 Hits@3:	1.000
# /medicine/disease/parent_disease:	 Hits@5:	1.000
# /medicine/disease/parent_disease:	 MRR:	0.944	 number of occurrence 9
# ################################
# /award/award_winner/awards_won./award/award_honor/ceremony:	 Hits@1:	1.000
# /award/award_winner/awards_won./award/award_honor/ceremony:	 Hits@3:	1.000
# /award/award_winner/awards_won./award/award_honor/ceremony:	 Hits@5:	1.000
# /award/award_winner/awards_won./award/award_honor/ceremony:	 MRR:	1.000	 number of occurrence 332
# ################################
# /tv/tv_actor/starring_roles./tv/regular_tv_appearance/series:	 Hits@1:	0.700
# /tv/tv_actor/starring_roles./tv/regular_tv_appearance/series:	 Hits@3:	1.000
# /tv/tv_actor/starring_roles./tv/regular_tv_appearance/series:	 Hits@5:	1.000
# /tv/tv_actor/starring_roles./tv/regular_tv_appearance/series:	 MRR:	0.823	 number of occurrence 140
# ################################
# /education/university/domestic_tuition./measurement_unit/dated_money_value/currency:	 Hits@1:	0.754
# /education/university/domestic_tuition./measurement_unit/dated_money_value/currency:	 Hits@3:	1.000
# /education/university/domestic_tuition./measurement_unit/dated_money_value/currency:	 Hits@5:	1.000
# /education/university/domestic_tuition./measurement_unit/dated_money_value/currency:	 MRR:	0.877	 number of occurrence 61
# ################################
# /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language:	 Hits@1:	0.905
# /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language:	 Hits@3:	1.000
# /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language:	 Hits@5:	1.000
# /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language:	 MRR:	0.952	 number of occurrence 21
# ################################
# /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics:	 Hits@1:	0.438
# /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics:	 Hits@3:	1.000
# /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics:	 Hits@5:	1.000
# /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics:	 MRR:	0.713	 number of occurrence 80
# ################################
# /people/deceased_person/cause_of_death:	 Hits@1:	0.978
# /people/deceased_person/cause_of_death:	 Hits@3:	1.000
# /people/deceased_person/cause_of_death:	 Hits@5:	1.000
# /people/deceased_person/cause_of_death:	 MRR:	0.989	 number of occurrence 92
# ################################
# /base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed:	 Hits@1:	1.000
# /base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed:	 Hits@3:	1.000
# /base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed:	 Hits@5:	1.000
# /base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed:	 MRR:	1.000	 number of occurrence 21
# ################################
# /film/film/other_crew./film/film_crew_gig/film_crew_role:	 Hits@1:	1.000
# /film/film/other_crew./film/film_crew_gig/film_crew_role:	 Hits@3:	1.000
# /film/film/other_crew./film/film_crew_gig/film_crew_role:	 Hits@5:	1.000
# /film/film/other_crew./film/film_crew_gig/film_crew_role:	 MRR:	1.000	 number of occurrence 691
# ################################
# /medicine/symptom/symptom_of:	 Hits@1:	0.969
# /medicine/symptom/symptom_of:	 Hits@3:	1.000
# /medicine/symptom/symptom_of:	 Hits@5:	1.000
# /medicine/symptom/symptom_of:	 MRR:	0.979	 number of occurrence 32
# ################################
# /music/group_member/membership./music/group_membership/role:	 Hits@1:	0.290
# /music/group_member/membership./music/group_membership/role:	 Hits@3:	1.000
# /music/group_member/membership./music/group_membership/role:	 Hits@5:	1.000
# /music/group_member/membership./music/group_membership/role:	 MRR:	0.580	 number of occurrence 69
# ################################
# /film/film/written_by:	 Hits@1:	0.208
# /film/film/written_by:	 Hits@3:	0.608
# /film/film/written_by:	 Hits@5:	0.925
# /film/film/written_by:	 MRR:	0.461	 number of occurrence 120
# ################################
# /music/instrument/instrumentalists:	 Hits@1:	0.815
# /music/instrument/instrumentalists:	 Hits@3:	1.000
# /music/instrument/instrumentalists:	 Hits@5:	1.000
# /music/instrument/instrumentalists:	 MRR:	0.906	 number of occurrence 254
# ################################
# /education/educational_degree/people_with_this_degree./education/education/student:	 Hits@1:	1.000
# /education/educational_degree/people_with_this_degree./education/education/student:	 Hits@3:	1.000
# /education/educational_degree/people_with_this_degree./education/education/student:	 Hits@5:	1.000
# /education/educational_degree/people_with_this_degree./education/education/student:	 MRR:	1.000	 number of occurrence 27
# ################################
# /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location:	 Hits@1:	0.854
# /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location:	 Hits@3:	1.000
# /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location:	 Hits@5:	1.000
# /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location:	 MRR:	0.915	 number of occurrence 41
# ################################
# /government/political_district/representatives./government/government_position_held/legislative_sessions:	 Hits@1:	1.000
# /government/political_district/representatives./government/government_position_held/legislative_sessions:	 Hits@3:	1.000
# /government/political_district/representatives./government/government_position_held/legislative_sessions:	 Hits@5:	1.000
# /government/political_district/representatives./government/government_position_held/legislative_sessions:	 MRR:	1.000	 number of occurrence 118
# ################################
# /location/location/adjoin_s./location/adjoining_relationship/adjoins:	 Hits@1:	0.849
# /location/location/adjoin_s./location/adjoining_relationship/adjoins:	 Hits@3:	0.954
# /location/location/adjoin_s./location/adjoining_relationship/adjoins:	 Hits@5:	0.989
# ...
# ################################
# /architecture/building_function/buildings:	 Hits@1:	0.000
# /architecture/building_function/buildings:	 Hits@3:	0.000
# /architecture/building_function/buildings:	 Hits@5:	1.000
# /architecture/building_function/buildings:	 MRR:	0.250	 number of occurrence 1
# ################################
# /architecture/structure/architectural_style:	 Hits@1:	1.000
# /architecture/structure/architectural_style:	 Hits@3:	1.000
# /architecture/structure/architectural_style:	 Hits@5:	1.000
# /architecture/structure/architectural_style:	 MRR:	1.000	 number of occurrence 1
# ################################
# /government/governmental_body/jurisdiction:	 Hits@1:	0.000
# /government/governmental_body/jurisdiction:	 Hits@3:	1.000
# /government/governmental_body/jurisdiction:	 Hits@5:	1.000
# /government/governmental_body/jurisdiction:	 MRR:	0.333	 number of occurrence 2
# ################################
# /common/topic/webpage./common/webpage/topic:	 Hits@1:	0.000
# /common/topic/webpage./common/webpage/topic:	 Hits@3:	0.000
# /common/topic/webpage./common/webpage/topic:	 Hits@5:	0.000
# /common/topic/webpage./common/webpage/topic:	 MRR:	0.062	 number of occurrence 1
# ################################
# /base/yalebase/secret_society_member/belonged_to./base/yalebase/secret_society_membership/society:	 Hits@1:	1.000
# /base/yalebase/secret_society_member/belonged_to./base/yalebase/secret_society_membership/society:	 Hits@3:	1.000
# /base/yalebase/secret_society_member/belonged_to./base/yalebase/secret_society_membership/society:	 Hits@5:	1.000
# /base/yalebase/secret_society_member/belonged_to./base/yalebase/secret_society_membership/society:	 MRR:	1.000	 number of occurrence 1
# ################################
# /people/cause_of_death/parent_cause_of_death:	 Hits@1:	0.000
# /people/cause_of_death/parent_cause_of_death:	 Hits@3:	1.000
# /people/cause_of_death/parent_cause_of_death:	 Hits@5:	1.000
# /people/cause_of_death/parent_cause_of_death:	 MRR:	0.500	 number of occurrence 2
# ################################
# /visual_art/visual_artist/associated_periods_or_movements:	 Hits@1:	1.000
# /visual_art/visual_artist/associated_periods_or_movements:	 Hits@3:	1.000
# /visual_art/visual_artist/associated_periods_or_movements:	 Hits@5:	1.000
# /visual_art/visual_artist/associated_periods_or_movements:	 MRR:	1.000	 number of occurrence 3
# ################################
# /architecture/architect/architectural_style:	 Hits@1:	1.000
# /architecture/architect/architectural_style:	 Hits@3:	1.000
# /architecture/architect/architectural_style:	 Hits@5:	1.000
# /architecture/architect/architectural_style:	 MRR:	1.000	 number of occurrence 1
# ################################
# /soccer/football_player/matches_played./soccer/football_player_match_participation/team:	 Hits@1:	0.000
# /soccer/football_player/matches_played./soccer/football_player_match_participation/team:	 Hits@3:	0.000
# /soccer/football_player/matches_played./soccer/football_player_match_participation/team:	 Hits@5:	1.000
# /soccer/football_player/matches_played./soccer/football_player_match_participation/team:	 MRR:	0.200	 number of occurrence 1
# ################################
# /basketball/basketball_player/team./basketball/basketball_roster_position/team:	 Hits@1:	0.000
# /basketball/basketball_player/team./basketball/basketball_roster_position/team:	 Hits@3:	0.000
# /basketball/basketball_player/team./basketball/basketball_roster_position/team:	 Hits@5:	0.000
# /basketball/basketball_player/team./basketball/basketball_roster_position/team:	 MRR:	0.111	 number of occurrence 2
# ################################
# /cvg/computer_videogame/prequel:	 Hits@1:	0.000
# /cvg/computer_videogame/prequel:	 Hits@3:	0.000
# /cvg/computer_videogame/prequel:	 Hits@5:	1.000
# /cvg/computer_videogame/prequel:	 MRR:	0.200	 number of occurrence 1
# ################################
# /base/fight/crime_type/people_convicted_of_this_crime./base/crime/criminal_conviction/convicted_person:	 Hits@1:	0.500
# /base/fight/crime_type/people_convicted_of_this_crime./base/crime/criminal_conviction/convicted_person:	 Hits@3:	1.000
# /base/fight/crime_type/people_convicted_of_this_crime./base/crime/criminal_conviction/convicted_person:	 Hits@5:	1.000
# /base/fight/crime_type/people_convicted_of_this_crime./base/crime/criminal_conviction/convicted_person:	 MRR:	0.750	 number of occurrence 2
# ################################
# /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/players:	 Hits@1:	0.000
# /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/players:	 Hits@3:	0.000
# /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/players:	 Hits@5:	1.000
# /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/players:	 MRR:	0.200	 number of occurrence 2
# ################################
# /people/cause_of_death/includes_causes_of_death:	 Hits@1:	0.000
# /people/cause_of_death/includes_causes_of_death:	 Hits@3:	1.000
# /people/cause_of_death/includes_causes_of_death:	 Hits@5:	1.000
# /people/cause_of_death/includes_causes_of_death:	 MRR:	0.333	 number of occurrence 1
# ################################
# /protected_sites/site_listing_category/listed_sites./protected_sites/natural_or_cultural_site_listing/listed_site:	 Hits@1:	1.000
# /protected_sites/site_listing_category/listed_sites./protected_sites/natural_or_cultural_site_listing/listed_site:	 Hits@3:	1.000
# /protected_sites/site_listing_category/listed_sites./protected_sites/natural_or_cultural_site_listing/listed_site:	 Hits@5:	1.000
# /protected_sites/site_listing_category/listed_sites./protected_sites/natural_or_cultural_site_listing/listed_site:	 MRR:	1.000	 number of occurrence 1
# ################################
# /fictional_universe/fictional_setting/works_set_here:	 Hits@1:	0.000
# /fictional_universe/fictional_setting/works_set_here:	 Hits@3:	0.500
# /fictional_universe/fictional_setting/works_set_here:	 Hits@5:	1.000
# /fictional_universe/fictional_setting/works_set_here:	 MRR:	0.292	 number of occurrence 2
# ################################
# /base/x2010fifaworldcupsouthafrica/world_cup_participant/world_cup_team./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/national_team:	 Hits@1:	0.000
# /base/x2010fifaworldcupsouthafrica/world_cup_participant/world_cup_team./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/national_team:	 Hits@3:	0.000
# /base/x2010fifaworldcupsouthafrica/world_cup_participant/world_cup_team./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/national_team:	 Hits@5:	0.000
# /base/x2010fifaworldcupsouthafrica/world_cup_participant/world_cup_team./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/national_team:	 MRR:	0.167	 number of occurrence 2
# ################################
# /cvg/computer_game_subject/games:	 Hits@1:	1.000
# /cvg/computer_game_subject/games:	 Hits@3:	1.000
# /cvg/computer_game_subject/games:	 Hits@5:	1.000
# /cvg/computer_game_subject/games:	 MRR:	1.000	 number of occurrence 1
# ################################
# /common/topic/subject_of:	 Hits@1:	0.000
# /common/topic/subject_of:	 Hits@3:	0.000
# /common/topic/subject_of:	 Hits@5:	0.000
# /common/topic/subject_of:	 MRR:	0.004	 number of occurrence 1
# ################################
# /travel/travel_destination/how_to_get_here./travel/transportation/transport_terminus:	 Hits@1:	0.000
# /travel/travel_destination/how_to_get_here./travel/transportation/transport_terminus:	 Hits@3:	1.000
# /travel/travel_destination/how_to_get_here./travel/transportation/transport_terminus:	 Hits@5:	1.000
# /travel/travel_destination/how_to_get_here./travel/transportation/transport_terminus:	 MRR:	0.500	 number of occurrence 1
# ################################
# /user/alexander/misc/murdered_person/place_murdered:	 Hits@1:	0.000
# /user/alexander/misc/murdered_person/place_murdered:	 Hits@3:	0.000
# /user/alexander/misc/murdered_person/place_murdered:	 Hits@5:	0.000
# /user/alexander/misc/murdered_person/place_murdered:	 MRR:	0.042	 number of occurrence 1
# ################################
# /tv/tv_actor/guest_roles./tv/tv_guest_role/episodes_appeared_in:	 Hits@1:	0.000
# /tv/tv_actor/guest_roles./tv/tv_guest_role/episodes_appeared_in:	 Hits@3:	0.000
# /tv/tv_actor/guest_roles./tv/tv_guest_role/episodes_appeared_in:	 Hits@5:	0.000
# /tv/tv_actor/guest_roles./tv/tv_guest_role/episodes_appeared_in:	 MRR:	0.045	 number of occurrence 1
# ################################
# /computer/operating_system/includes_os_versions:	 Hits@1:	1.000
# /computer/operating_system/includes_os_versions:	 Hits@3:	1.000
# /computer/operating_system/includes_os_versions:	 Hits@5:	1.000
# /computer/operating_system/includes_os_versions:	 MRR:	1.000	 number of occurrence 1
# ################################
# /base/popstra/celebrity/bought./base/popstra/product_choice/product:	 Hits@1:	0.000
# /base/popstra/celebrity/bought./base/popstra/product_choice/product:	 Hits@3:	0.000
# /base/popstra/celebrity/bought./base/popstra/product_choice/product:	 Hits@5:	0.000
# /base/popstra/celebrity/bought./base/popstra/product_choice/product:	 MRR:	0.167	 number of occurrence 1
# ################################
# /architecture/museum/type_of_museum:	 Hits@1:	1.000
# /architecture/museum/type_of_museum:	 Hits@3:	1.000
# /architecture/museum/type_of_museum:	 Hits@5:	1.000
# /architecture/museum/type_of_museum:	 MRR:	1.000	 number of occurrence 1
# ################################
# /people/appointee/position./people/appointment/appointed_by:	 Hits@1:	0.000
# /people/appointee/position./people/appointment/appointed_by:	 Hits@3:	0.000
# /people/appointee/position./people/appointment/appointed_by:	 Hits@5:	0.000
# /people/appointee/position./people/appointment/appointed_by:	 MRR:	0.004	 number of occurrence 1
# ################################
# /education/academic/research_areas:	 Hits@1:	0.000
# /education/academic/research_areas:	 Hits@3:	1.000
# /education/academic/research_areas:	 Hits@5:	1.000
# /education/academic/research_areas:	 MRR:	0.333	 number of occurrence 1
# ################################
# /education/educational_institution/mascot:	 Hits@1:	0.000
# /education/educational_institution/mascot:	 Hits@3:	1.000
# /education/educational_institution/mascot:	 Hits@5:	1.000
# /education/educational_institution/mascot:	 MRR:	0.500	 number of occurrence 1
# ################################
# /user/szaijan/fantasy_football/player/nfl_team:	 Hits@1:	1.000
# /user/szaijan/fantasy_football/player/nfl_team:	 Hits@3:	1.000
# /user/szaijan/fantasy_football/player/nfl_team:	 Hits@5:	1.000
# /user/szaijan/fantasy_football/player/nfl_team:	 MRR:	1.000	 number of occurrence 1
# ################################
# /base/popstra/product/sold_to./base/popstra/product_choice/consumer:	 Hits@1:	0.000
# /base/popstra/product/sold_to./base/popstra/product_choice/consumer:	 Hits@3:	1.000
# /base/popstra/product/sold_to./base/popstra/product_choice/consumer:	 Hits@5:	1.000
# /base/popstra/product/sold_to./base/popstra/product_choice/consumer:	 MRR:	0.500	 number of occurrence 1
# ################################
# /sports/tournament_event_competitor/events_competed_in./sports/competitor_competition_relationship/country:	 Hits@1:	0.000
# /sports/tournament_event_competitor/events_competed_in./sports/competitor_competition_relationship/country:	 Hits@3:	0.000
# /sports/tournament_event_competitor/events_competed_in./sports/competitor_competition_relationship/country:	 Hits@5:	0.000
# /sports/tournament_event_competitor/events_competed_in./sports/competitor_competition_relationship/country:	 MRR:	0.143	 number of occurrence 1
# ################################
# /book/author/works_written:	 Hits@1:	0.000
# /book/author/works_written:	 Hits@3:	0.000
# /book/author/works_written:	 Hits@5:	0.000
# /book/author/works_written:	 MRR:	0.167	 number of occurrence 1
# ################################
# /travel/travel_destination/local_transportation:	 Hits@1:	0.000
# /travel/travel_destination/local_transportation:	 Hits@3:	0.000
# /travel/travel_destination/local_transportation:	 Hits@5:	0.000
# /travel/travel_destination/local_transportation:	 MRR:	0.111	 number of occurrence 1
# ################################
# /film/actor/dubbing_performances./film/dubbing_performance/character:	 Hits@1:	0.000
# /film/actor/dubbing_performances./film/dubbing_performance/character:	 Hits@3:	0.000
# /film/actor/dubbing_performances./film/dubbing_performance/character:	 Hits@5:	0.000
# /film/actor/dubbing_performances./film/dubbing_performance/character:	 MRR:	0.100	 number of occurrence 1
# ################################
# /base/thoroughbredracing/thoroughbred_racehorse/sex:	 Hits@1:	0.000
# /base/thoroughbredracing/thoroughbred_racehorse/sex:	 Hits@3:	0.000
# /base/thoroughbredracing/thoroughbred_racehorse/sex:	 Hits@5:	0.000
# /base/thoroughbredracing/thoroughbred_racehorse/sex:	 MRR:	0.056	 number of occurrence 1
# ################################
# /american_football/football_player/receiving./american_football/player_receiving_statistics/season:	 Hits@1:	0.000
# /american_football/football_player/receiving./american_football/player_receiving_statistics/season:	 Hits@3:	0.000
# /american_football/football_player/receiving./american_football/player_receiving_statistics/season:	 Hits@5:	0.000
# /american_football/football_player/receiving./american_football/player_receiving_statistics/season:	 MRR:	0.048	 number of occurrence 1
# ################################
# /user/radiusrs/default_domain/astrology/related_topics:	 Hits@1:	0.000
# /user/radiusrs/default_domain/astrology/related_topics:	 Hits@3:	0.000
# /user/radiusrs/default_domain/astrology/related_topics:	 Hits@5:	0.000
# /user/radiusrs/default_domain/astrology/related_topics:	 MRR:	0.008	 number of occurrence 1
# ################################
# /internet/website/owner_new./internet/website_ownership/owner:	 Hits@1:	0.000
# /internet/website/owner_new./internet/website_ownership/owner:	 Hits@3:	0.000
# /internet/website/owner_new./internet/website_ownership/owner:	 Hits@5:	0.000
# /internet/website/owner_new./internet/website_ownership/owner:	 MRR:	0.067	 number of occurrence 1
# ################################
# /fictional_universe/fictional_character/occupation:	 Hits@1:	1.000
# /fictional_universe/fictional_character/occupation:	 Hits@3:	1.000
# /fictional_universe/fictional_character/occupation:	 Hits@5:	1.000
# /fictional_universe/fictional_character/occupation:	 MRR:	1.000	 number of occurrence 1
# ################################
# /cvg/gameplay_mode/games_with_this_mode:	 Hits@1:	1.000
# /cvg/gameplay_mode/games_with_this_mode:	 Hits@3:	1.000
# /cvg/gameplay_mode/games_with_this_mode:	 Hits@5:	1.000
# /cvg/gameplay_mode/games_with_this_mode:	 MRR:	1.000	 number of occurrence 1
# ################################
# /astronomy/orbital_relationship/orbits:	 Hits@1:	0.000
# /astronomy/orbital_relationship/orbits:	 Hits@3:	0.000
# /astronomy/orbital_relationship/orbits:	 Hits@5:	0.000
# /astronomy/orbital_relationship/orbits:	 MRR:	0.125	 number of occurrence 1
# ################################
# /baseball/baseball_league/teams:	 Hits@1:	0.000
# /baseball/baseball_league/teams:	 Hits@3:	1.000
# /baseball/baseball_league/teams:	 Hits@5:	1.000
# /baseball/baseball_league/teams:	 MRR:	0.500	 number of occurrence 1
# ################################
# /government/government_office_or_title/jurisdiction:	 Hits@1:	0.000
# /government/government_office_or_title/jurisdiction:	 Hits@3:	1.000
# /government/government_office_or_title/jurisdiction:	 Hits@5:	1.000
# /government/government_office_or_title/jurisdiction:	 MRR:	0.500	 number of occurrence 1
# ################################
# /base/popstra/celebrity/eats_at./base/popstra/restaurant_choice/restaurant:	 Hits@1:	1.000
# /base/popstra/celebrity/eats_at./base/popstra/restaurant_choice/restaurant:	 Hits@3:	1.000
# /base/popstra/celebrity/eats_at./base/popstra/restaurant_choice/restaurant:	 Hits@5:	1.000
# /base/popstra/celebrity/eats_at./base/popstra/restaurant_choice/restaurant:	 MRR:	1.000	 number of occurrence 1
# ################################
